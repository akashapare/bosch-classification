# %%
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/dataset.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('/tmp') #Extracts the files into the /tmp folder
zip_ref.close()

# %%
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
import numpy as np

import matplotlib.pyplot as plt

# %%
path='/tmp/dataset'
validation=keras.preprocessing.image_dataset_from_directory(path,labels='inferred',label_mode='categorical',batch_size=20,validation_split=.2,subset='validation',smart_resize=True,seed=1337)
training=keras.preprocessing.image_dataset_from_directory(path,labels='inferred',label_mode='categorical',batch_size=20,validation_split=.2,subset='training',smart_resize=True,seed=1337)
# Out:
# Found 3432 files belonging to 5 classes.
# Using 686 files for validation.
# Found 3432 files belonging to 5 classes.
# Using 2746 files for training.

# %%
from glob import glob
import numpy as np
import os
import sys

# You'll need scikit-image and PIL installed to use this
try:
    import skimage.io
except ImportError:
    sys.exit("please 'pip install scikit-image' to use this script")


def median(pattern, outfile):
    c = skimage.io.ImageCollection(pattern)
    all_images = c.concatenate()
    median = np.median(all_images, axis=0)

    m = np.array(median, dtype=np.uint8)
    skimage.io.imsave(outfile, m)
    print(outfile)


def average(images, outfile):
    average = np.array(skimage.io.imread(images[0]), dtype=np.float32)

    n = 1
    for i, img in enumerate(images[1:]):
        try:
            im = skimage.io.imread(img)
            print(img)
            average += im
            n += 1
        except: 
          pass
   
    average /= float(n)

    a = np.array(average, dtype=np.uint8)
    skimage.io.imsave(outfile, a)
    print(outfile)


def main():
    folder ='/tmp/dataset/default' 
    pattern = os.path.join(folder, "*.jpg")
    average(glob(pattern), os.path.join(folder, "average.jpg"))
    median(pattern, os.path.join(folder, "median.jpg"))


if __name__ == '__main__':
    main()
# Out:
# /tmp/dataset/gps/080721img39690.jpg
# /tmp/dataset/gps/080721img22830.jpg
# /tmp/dataset/gps/080721img21900.jpg
# /tmp/dataset/gps/080721img37965.jpg
# /tmp/dataset/gps/080721img20520.jpg
# /tmp/dataset/gps/080721img21870.jpg
# /tmp/dataset/gps/080721img71625.jpg
# /tmp/dataset/gps/080721img38175.jpg
# /tmp/dataset/gps/080721img38610.jpg
# /tmp/dataset/gps/080721img38070.jpg
# /tmp/dataset/gps/080721img59775.jpg
# /tmp/dataset/gps/080721img22230.jpg
# /tmp/dataset/gps/080721img60150.jpg
# /tmp/dataset/gps/080721img39390.jpg
# /tmp/dataset/gps/080721img39570.jpg
# /tmp/dataset/gps/080721img60750.jpg
# /tmp/dataset/gps/080721img20610.jpg
# /tmp/dataset/gps/080721img22455.jpg
# /tmp/dataset/gps/080721img21705.jpg
# /tmp/dataset/gps/080721img60735.jpg
# /tmp/dataset/gps/080721img64995.jpg
# /tmp/dataset/gps/080721img37560.jpg
# /tmp/dataset/gps/080721img38940.jpg
# /tmp/dataset/gps/080721img37740.jpg
# /tmp/dataset/gps/080721img20340.jpg
# /tmp/dataset/gps/080721img22980.jpg
# /tmp/dataset/gps/080721img65220.jpg
# /tmp/dataset/gps/080721img36390.jpg
# /tmp/dataset/gps/080721img22275.jpg
# /tmp/dataset/gps/080721img60030.jpg
# /tmp/dataset/gps/080721img20730.jpg
# /tmp/dataset/gps/080721img20010.jpg
# /tmp/dataset/gps/080721img21570.jpg
# /tmp/dataset/gps/080721img36915.jpg
# /tmp/dataset/gps/080721img37080.jpg
# /tmp/dataset/gps/080721img20775.jpg
# /tmp/dataset/gps/080721img38655.jpg
# /tmp/dataset/gps/080721img23400.jpg
# /tmp/dataset/gps/080721img20370.jpg
# /tmp/dataset/gps/080721img37170.jpg
# /tmp/dataset/gps/080721img60120.jpg
# /tmp/dataset/gps/080721img39675.jpg
# /tmp/dataset/gps/080721img21915.jpg
# /tmp/dataset/gps/080721img60690.jpg
# /tmp/dataset/gps/080721img20310.jpg
# /tmp/dataset/gps/080721img60450.jpg
# /tmp/dataset/gps/080721img19860.jpg
# /tmp/dataset/gps/080721img39210.jpg
# /tmp/dataset/gps/080721img60045.jpg
# /tmp/dataset/gps/080721img20490.jpg
# /tmp/dataset/gps/080721img21195.jpg
# /tmp/dataset/gps/080721img39045.jpg
# /tmp/dataset/gps/080721img38415.jpg
# /tmp/dataset/gps/080721img38325.jpg
# /tmp/dataset/gps/080721img23340.jpg
# /tmp/dataset/gps/080721img22635.jpg
# /tmp/dataset/gps/080721img64920.jpg
# /tmp/dataset/gps/080721img64965.jpg
# /tmp/dataset/gps/080721img71385.jpg
# /tmp/dataset/gps/080721img21210.jpg
# /tmp/dataset/gps/080721img37125.jpg
# /tmp/dataset/gps/080721img60255.jpg
# /tmp/dataset/gps/080721img65460.jpg
# /tmp/dataset/gps/080721img88275.jpg
# /tmp/dataset/gps/080721img38100.jpg
# /tmp/dataset/gps/080721img21285.jpg
# /tmp/dataset/gps/080721img65175.jpg
# /tmp/dataset/gps/080721img39165.jpg
# /tmp/dataset/gps/080721img36660.jpg
# /tmp/dataset/gps/080721img37815.jpg
# /tmp/dataset/gps/080721img21015.jpg
# /tmp/dataset/gps/average.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/skimage/io/collection.py in concatenate_images(ic)
#      48     try:
# ---> 49         array_cat = np.concatenate(all_images)
#      50     except ValueError:
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 352 and the array at index 4 has size 720
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-326ae1261601> in <module>()
#      49
#      50 if __name__ == '__main__':
# ---> 51     main()
#
# <ipython-input-18-326ae1261601> in main()
#      45     pattern = os.path.join(folder, "*.jpg")
#      46     average(glob(pattern), os.path.join(folder, "average.jpg"))
# ---> 47     median(pattern, os.path.join(folder, "median.jpg"))
#      48
#      49
#
# <ipython-input-18-326ae1261601> in median(pattern, outfile)
#      13 def median(pattern, outfile):
#      14     c = skimage.io.ImageCollection(pattern)
# ---> 15     all_images = c.concatenate()
#      16     median = np.median(all_images, axis=0)
#      17
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/collection.py in concatenate(self)
#     364             If images in the `ImageCollection` don't have identical shapes.
#     365         """
# --> 366         return concatenate_images(self)
#     367
#     368
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/collection.py in concatenate_images(ic)
#      49         array_cat = np.concatenate(all_images)
#      50     except ValueError:
# ---> 51         raise ValueError('Image dimensions must agree.')
#      52     return array_cat
#      53
#
# ValueError: Image dimensions must agree.
